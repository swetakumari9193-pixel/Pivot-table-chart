# %% [markdown]
# 1.What is the purpose of a PivotTable in Excel?
# Ans-PivotTable helps in analyzing the large data in a simple form. It also gives as quick report for decision making.

# %% [markdown]
# 2.Create a PivotTable to show Total Sales by Region.
# Ans-

# %% [markdown]
# 3.Apply Conditional Formatting to highlight sales greater than 400.

# %% [markdown]
# 4.Explain the difference between Sorting and Filtering with an example from this dataset.
# Ans-Sorting- sorting means arranging the given data in a particular formate. Examples increasing or decreasing order of there sale.
# Filtering- filtering is a drop down list in excel which allows as to see only the required data or choise of data at a time.

# %% [markdown]
# 7.Why are Dashboards important for decision-making in business analysis?
# Ans-Dashboard helps us in analysing the data provides more information on decision making. It also provides as in better collaboration real-time monitering and goal setting. On addition it is save time and resources.
